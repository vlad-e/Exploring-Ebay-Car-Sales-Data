# %% [markdown]
# # Clean data and analyze the used-cars list from German E-Bay (Ja!)
#
# First, let's read the file in Pandas and investigate the data a litte

# %%
import numpy as np
import pandas as pd

# %%
autos = pd.read_csv("autos.csv", encoding = "Latin-1")

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
autos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %% [markdown]
#  Can tell we can clean somehow the columns : Split the NAME (Brand, Model, Engine) ; clean the ODOMETER , etc
#
#  Let's analyze the columns first, and rename them

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.columns = ['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
       'vehicleType', 'registration_year', 'gearbox', 'powerPS', 'model',
       'odometer', 'registration_month', 'fuelType', 'brand',
       'unrepaired_damage', 'ad_created', 'nrOfPictures', 'postalCode',
       'lastSeen']

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'registration_year', 'gearbox', 'powerPS', 'model',
#        'odometer', 'registration_month', 'fuelType', 'brand',
#        'unrepaired_damage', 'ad_created', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %% [markdown]
# Ok, this worked, now let's see the next bit...
# Let's get a descriptive statistics for all columns:

# %%
autos.describe(include = 'all')
# Out:
#                 dateCrawled         name  seller offerType  price abtest  \
# count                 50000        50000   50000     50000  50000  50000
# unique                48213        38754       2         2   2357      2
# top     2016-03-14 20:50:02  Ford_Fiesta  privat   Angebot     $0   test
# freq                      3           78   49999     49999   1421  25756
# mean                    NaN          NaN     NaN       NaN    NaN    NaN
# std                     NaN          NaN     NaN       NaN    NaN    NaN
# min                     NaN          NaN     NaN       NaN    NaN    NaN
# 25%                     NaN          NaN     NaN       NaN    NaN    NaN
# 50%                     NaN          NaN     NaN       NaN    NaN    NaN
# 75%                     NaN          NaN     NaN       NaN    NaN    NaN
# max                     NaN          NaN     NaN       NaN    NaN    NaN
#
#        vehicleType  registration_year  gearbox       powerPS  model  \
# ...

# %% [markdown]
# Ok, from what i see:
#     - seller / offertype -> just two values
#     - price needs fixing (values of 0) + convert to number
#     - abtest -> just two values
#     - registration_year -> convert to integer, no decimals
#     - gearbox -> two values
#     - powerps needs convertion
#     - odometer needs cleaning (remove km)
#     - registration_month needs conversion
#     - brand repeats info from other column
#     - no_of_pictures can be dropped
#     - postal code needs conversion

# %%
autos["price"].value_counts()
# Out:
# $0         1421
# $500        781
# $1,500      734
# $2,500      643
# $1,000      639
# $1,200      639
# $600        531
# $3,500      498
# $800        498
# $2,000      460
# $999        434
# $750        433
# $900        420
# $650        419
# $850        410
# $700        395
# $4,500      394
# $300        384
# $2,200      382
# $950        379
# $1,100      376
# $1,300      371
# $3,000      365
# $550        356
# $1,800      355
# $5,500      340
# $1,250      335
# $350        335
# $1,600      327
# $1,999      322
#            ...
# $2,001        1
# $88,900       1
# $12,580       1
# $48,490       1
# $13,520       1
# $24,480       1
# $19,399       1
# $35,911       1
# $10,498       1
# $18,430       1
# $1,645        1
# $35,222       1
# $36,675       1
# $1,930        1
# $6,039        1
# $6,460        1
# $13,560       1
# $31,200       1
# $4,567        1
# $1,325        1
# $248          1
# $67,000       1
# $9,989        1
# $1,760        1
# ...

# %%
autos["odometer"].value_counts()
# Out:
# 150,000km    32424
# 125,000km     5170
# 100,000km     2169
# 90,000km      1757
# 80,000km      1436
# 70,000km      1230
# 60,000km      1164
# 50,000km      1027
# 5,000km        967
# 40,000km       819
# 30,000km       789
# 20,000km       784
# 10,000km       264
# Name: odometer, dtype: int64

# %% [markdown]
# We will convert values in PRICE and ODOMETER to numeric, by removing the text, changing the"," to "." and making them float

# %%
autos["price"] = autos["price"].str.replace("$","").str.replace(",","").astype(float)
autos["odometer"] = autos["odometer"].str.replace("km","").str.replace(",","").astype(float)
autos.rename({"odometer":"odometer_km"},axis=1)
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %% [markdown]
# Continuing on PRICE and ODOMETER, we make another analysis of the data values

# %%
autos["price"].unique().shape
# Out:
# (2357,)

# %%
autos["odometer"].unique().shape
# Out:
# (13,)

# %%
autos["price"].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %% [markdown]
# OK, we can see we have cars with price 0 as i have said. We might need to drop those rows

# %%
autos["odometer"].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer, dtype: float64

# %% [markdown]
# pretty rough values, not much to clean here , i guess

# %% [markdown]
# Let's try to remove the 0 values from price (maybe also the big one of 10^8

# %%
autos["price"].value_counts().sort_index(ascending=True).head(20)
# Out:
# 0.0     1421
# 1.0      156
# 2.0        3
# 3.0        1
# 5.0        2
# 8.0        1
# 9.0        1
# 10.0       7
# 11.0       2
# 12.0       3
# 13.0       2
# 14.0       1
# 15.0       2
# 17.0       3
# 18.0       1
# 20.0       4
# 25.0       5
# 29.0       1
# 30.0       7
# 35.0       1
# Name:
str[:10].value_counts(normalize = True, dropna = False).sort_index(ascending = False)
# Out:
# 2016-04-07    0.131947
# 2016-04-06    0.221806
# 2016-04-05    0.124761
# 2016-04-04    0.024483
# 2016-04-03    0.025203
# 2016-04-02    0.024915
# 2016-04-01    0.022794
# 2016-03-31    0.023783
# 2016-03-30    0.024771
# 2016-03-29    0.022341
# 2016-03-28    0.020859
# 2016-03-27    0.015649
# 2016-03-26    0.016802
# 2016-03-25    0.019211
# 2016-03-24    0.019767
# 2016-03-23    0.018532
# 2016-03-22    0.021373
# 2016-03-21    0.020632
# 2016-03-20    0.020653
# 2016-03-19    0.015834
# 2016-03-18    0.007351
# 2016-03-17    0.028086
# 2016-03-16    0.016452
# 2016-03-15    0.015876
# 2016-03-14    0.012602
# 2016-03-13    0.008895
# 2016-03-12    0.023783
# 2016-03-11    0.012375
# 2016-03-10    0.010666
# 2016-03-09    0.009595
# 2016-03-08    0.007413
# 2016-03-07    0.005395
# 2016-03-06    0.004324
# 2016-03-05    0.001071
# Name: lastSeen, dtype: float64

# %% [markdown]
# Well...nice dates, what can I say ?! :)
#
# Now for registration year

# %%
autos["registration_year"].describe()
# Out:
# count    48565.000000
# mean      2004.755421
# std         88.643887
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# OK, some of them are deadly wrong... we'll see

# %%
autos["registration_year"].value_counts().sort_index().head(20)
# Out:
# 1000    1
# 1001    1
# 1111    1
# 1800    2
# 1910    5
# 1927    1
# 1929    1
# 1931    1
# 1934    2
# 1937    4
# 1938    1
# 1939    1
# 1941    2
# 1943    1
# 1948    1
# 1950    3
# 1951    2
# 1952    1
# 1953    1
# 1954    2
# Name: registration_year, dtype: int64

# %%
autos = autos[autos["registration_year"].between(1950,2016)]

# %%
autos["registration_year"].describe()
# Out:
# count    46661.000000
# mean      2002.941943
# std          7.022165
# min       1950.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       2016.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# OK, we fixed the year...onwards!

# %%
autos["name"].str.split("_",expand=True).iloc[:,0].value_counts(normalize=True).head(10)
# Out:
# Volkswagen    0.106127
# Opel          0.088596
# BMW           0.087675
# Mercedes      0.082189
# Audi          0.075395
# Ford          0.058893
# VW            0.040526
# Renault       0.038255
# Peugeot       0.025760
# Fiat          0.021688
# Name: 0, dtype: float64

# %% [markdown]
# This is value count of all car names / brands = so let's see what we cna do... 10% VW, 9 % Opel, BMW, Mercedes and 7% Audi...i think that's cool enough...

# %%
brand_counts = autos["brand"].value_counts(normalize=True)
common_brands = brand_counts[brand_counts > .05].index
for
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %%
brand_mean_prices = {}
brand_mean_mileage = {}
for brand in common_brands:
    brand_only = autos[autos["brand"] == brand]
    mean_price = brand_only["price"].mean()
    mean_mileage= brand_only["odometer"].mean()
    brand_mean_prices[brand] = int(mean_price)
    brand_mean_mileage[brand] = int(mean_mileage)
brand_mean_prices
brand_mean_mileage
# Out:
# {'audi': 129157,
#  'bmw': 132597,
#  'ford': 124374,
#  'mercedes_benz': 130832,
#  'opel': 129336,
#  'volkswagen': 128710}

# %% [markdown]
# OK, i cheated on this one and got the answer cause I didn't remember, plus it's late, and plus I'm sleepy

# %%
bmp_series = pd.Series(brand_mean_prices)
bmm_series = pd.Series(brand_mean_mileage)

# %%
brand_info = pd.DataFrame(bmp_series,columns=["mean_price"])
brand_info=pd.DataFrame(bmm_series,columns=["mean_mileage"])

# %%
brand_info
# Out:
#                mean_mileage
# audi                 129157
# bmw                  132597
# ford                 124374
# mercedes_benz        130832
# opel                 129336
# volkswagen           128710
